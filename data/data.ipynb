# %%
import numpy as np

import pandas as pd
from pandas.api.types import CategoricalDtype

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

import zipfile
import os

data = pd.read_csv("california_wine_production.csv")

data.head()
# Out:
#    Year  CommodityCode    CropName  CountyCode   County  HarvestedAcres  \
# 0  2020         216299  GRAPESWINE           1  Alameda          2530.0
# 1  2019         216299  GRAPESWINE           1  Alameda          3390.0
# 2  2018         216299  GRAPESWINE           1  Alameda          3390.0
# 3  2017         216299  GRAPESWINE           1  Alameda          2420.0
# 4  2016         216299  GRAPESWINE           1  Alameda          2630.0
#
#    Yield(Unit/Acre)  Production  Price(Dollars/Unit)  Unit  Value(Dollars)  \
# 0              5.14     13000.0              1497.69  TONS        19470000
# 1              5.34     18100.0              1503.04  TONS        27205000
# 2              5.34     18100.0              1503.04  TONS        27205000
# 3              5.08     12300.0              1447.32  TONS        17802000
# 4              4.83     12700.0              1432.20  TONS        18189000
#
#        lat      long
# 0  37.6469 -121.8888
# 1  37.6469 -121.8888
# 2  37.6469 -121.8888
# 3  37.6469 -121.8888
# 4  37.6469 -121.8888

# %%
# want to reorder the years the opposite way
data_year = data.groupby('County')[['Year', 'HarvestedAcres', 'Yield(Unit/Acre)']]
data_year.head()
# Out:
#       Year  HarvestedAcres  Yield(Unit/Acre)
# 0     2020          2530.0              5.14
# 1     2019          3390.0              5.34
# 2     2018          3390.0              5.34
# 3     2017          2420.0              5.08
# 4     2016          2630.0              4.83
# ...    ...             ...               ...
# 1301  2011            57.0              2.19
# 1302  2010            76.0              4.30
# 1303  2009            91.0              3.87
# 1304  2008            91.0              1.27
# 1305  2007            85.0              1.36
#
# [199 rows x 3 columns]

# %%
def reversing(x):
    x['Year'] = x['Year'].iloc[::-1].values
    return x

data = data.groupby('County', sort = False).apply(reversing)
data.head()
# Out:
#    Year  CommodityCode    CropName  CountyCode   County  HarvestedAcres  \
# 0  1980         216299  GRAPESWINE           1  Alameda          2530.0
# 1  1981         216299  GRAPESWINE           1  Alameda          3390.0
# 2  1982         216299  GRAPESWINE           1  Alameda          3390.0
# 3  1983         216299  GRAPESWINE           1  Alameda          2420.0
# 4  1984         216299  GRAPESWINE           1  Alameda          2630.0
#
#    Yield(Unit/Acre)  Production  Price(Dollars/Unit)  Unit  Value(Dollars)  \
# 0              5.14     13000.0              1497.69  TONS        19470000
# 1              5.34     18100.0              1503.04  TONS        27205000
# 2              5.34     18100.0              1503.04  TONS        27205000
# 3              5.08     12300.0              1447.32  TONS        17802000
# 4              4.83     12700.0              1432.20  TONS        18189000
#
#        lat      long
# 0  37.6469 -121.8888
# 1  37.6469 -121.8888
# 2  37.6469 -121.8888
# 3  37.6469 -121.8888
# 4  37.6469 -121.8888

# %%
data.to_csv('california_wine_production.zip', index = False)
